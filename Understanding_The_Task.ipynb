# %% [markdown]
# ### NOTES
# ---
# Reference: [CodeBERT + Pairwise](https://www.kaggle.com/code/devrimzay/codebert-pairwise)

# %% [markdown]
# #### LIBRARIES

# %%
import re
import json
import numpy as np
import pandas as pd
from tqdm import tqdm
from pathlib import Path
from scipy import sparse

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import GroupShuffleSplit

import nltk
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# #### UTILITIES

# %%
def read_notebook(path):
    """
    Read the notebook JSON content.
    """
    return (
        pd.read_json(
            path,
            dtype={'cell_type': 'category', 'source': 'str'})
        .assign(id=path.stem)
        .rename_axis('cell_id')
    )


def encode_orders(raw_data_order, ground_truth_order):
    """
    Encode the cell orders from cell_ids to numerical values.
    
    Parameters
    ----------
    raw_data_order
        The cell order as per the raw JSON data.
    ground_truth_order
        The actual logical cell order.
        
    Returns
    -------
    The encoded numerical order.
    """
    return [ground_truth_order.index(cell) for cell in raw_data_order]

# %% [markdown]
# #### DATA

# %%
data_dir = Path.cwd()/"AI4Code"
train_dir = data_dir/"train"

# Train orders.
train_orders = pd.read_csv(
    data_dir / 'train_orders.csv',
    index_col='id'
).squeeze().str.split()

# Train ancestors
train_ancestors = pd.read_csv(data_dir / 'train_ancestors.csv', index_col='id')

# %% [markdown]
# ### UNPACKING PROCESS

# %%
# Starting samples.
samples = 300

# %%
# Sample paths.
paths_train = list((train_dir).glob('*.json'))[:samples]
notebooks_train = [read_notebook(path) for path in tqdm(paths_train, desc='Loading')]
# Out:
# Loading: 100%|██████████████████████████████████████████████████████████████████████| 300/300 [00:01<00:00, 258.30it/s]

# %%
notebooks_train[0]
# Out:
#          cell_type                                             source  \
# cell_id
# 1862f0a6      code  # This Python 3 environment comes with many he...
# 2a9e43d6      code  import numpy as np\nimport pandas as pd\nimpor...
# 038b763d      code  import warnings\nwarnings.filterwarnings('igno...
# 2eefe0ef      code      matplotlib.rcParams.update({'font.size': 14})
# 0beab1cd      code  def evaluate_preds(train_true_values, train_pr...
# 9a78ab76      code  TRAIN_DATASET_PATH = '/kaggle/input/real-estat...
# ebe125d5      code  train_df = pd.read_csv(TRAIN_DATASET_PATH)\ntr...
# d9dced8b      code                                    train_df.dtypes
# 86497fe1      code  num_feat = list(train_df.select_dtypes(exclude...
# e2c8e725      code  test_df = pd.read_csv(TEST_DATASET_PATH)\ntest...
# ff7c44ed      code  print('Строк в трейне:', train_df.shape[0])\np...
# 0e7c906e      code          train_df.shape[1] - 1 == test_df.shape[1]
# dd0c804a      code  submission_df = pd.read_csv('/kaggle/input/rea...
# 781bbf3c      code        train_df['Id'] = train_df['Id'].astype(str)
# bd94f005      code  train_df[num_feat].hist(\n    figsize=(16,16)\...
# 62638fba      code                              train_df.describe().T
# bb69e88c      code  grid = sns.jointplot(train_df['Rooms'], train_...
# 6b5664c7      code  grid = sns.jointplot(train_df['KitchenSquare']...
# 23783525      code  train_df_temp = train_df.loc[train_df['Kitchen...
# 8522781a      code  plt.figure(figsize = (16, 8))\n\ntrain_df['Pri...
# 8ca8392c      code  correlation = train_df.corrwith(train_df['Pric...
# 17ec3fc4      code  class Data:\n    \n    def __init__(self):\n  ...
# 76512d50      code  data_inst = Data()\n\n# тренировочные данные\n...
# a98c5d9f      code  feature_names = ['AverageSquareMeterPrice', 'D...
# 06365725      code  train_df = train_df[feature_names + [target_na...
# 59959af5      code  final_model = CatBoostRegressor(\n    silent=T...
# 80151ab7      code          print(f'R2: {round(cv_score.mean(), 3)}')
# 5bf9ca51      code  feature_importances = pd.DataFrame(\n    zip(X...
# f5504853      code  preds_final = pd.DataFrame()\npreds_final['Id'...
# 9f50dca0      code  y_pred_final = final_model.predict(test_df)\n\...
# 21616367  markdown        *Деление признаков на числовые и текстовые*
# fcb6792d  markdown               **Сортировка признаков по важности**
# 63c26fa2  markdown  Выбросы наблюдаются в: HouseYear, KitchenSquar...
# 4bb2e30a  markdown                    **Поиск признаков с выбросами**
# a6357f7e  markdown        *Выводим сколько строк в тесте и на трейне*
# 45082c89  markdown                               **Приведение типов**
# 77e56113  markdown  **Устанавливаем значения, чтобы везде был один...
# 448eb224  markdown  **Импортируем необходимые для работы функции и...
# 032e2820  markdown  Создаем список признаков, используемых в модел...
# 8554b284  markdown  **Обучение модели на CatBoostRegressor**\n\nВы...
# 36002912  markdown  За выброс посчитаем значения менее 3 кв.м. и б...
# ac301a84  markdown  *На обучении на один признак больше, чем на те...
# 23705731  markdown               **Считываем обучающий набор данных**
# 1496beaf  markdown                                         Корреляция
# 2e1a5949  markdown                                      Оценка модели
# 7e2f170a  markdown                      **Подключаем предупреждения**
# bfbde93e  markdown  **График распределения целевой переменной - це...
# 0d136e08  markdown                                **Загрузка данных**
# 915643b3  markdown           **Создание датафрейма с предсказаниями**
# 8ffe0b25  markdown              **Указываем путь к файлам с данными**
# 8a4c95d1  markdown  *Описание датасета*\n\n**Id** - идентификацион...
# b69a4f9b  markdown                  Создания класса подготовки данных
# c3ce0945  markdown                **Считываем тестовый набор данных**
# 3eebeb87  markdown            Значения меньше 1 и больше 250 отсекаем
# 1ae087ab  markdown             **Задаем функцию для подсчета метрик**
# aaad8355  markdown                       *Тип данных обучающего сета*
# 503926eb  markdown                          Инициализация класса Data
# 3e5f860d  markdown  Признаки Rooms, KitchenSquare, HouseFloor имею...
#
#                       id
# cell_id
# 1862f0a6  00001756c60be8
# 2a9e43d6  00001756c60be8
# 038b763d  00001756c60be8
# 2eefe0ef  00001756c60be8
# 0beab1cd  00001756c60be8
# 9a78ab76  00001756c60be8
# ebe125d5  00001756c60be8
# d9dced8b  00001756c60be8
# 86497fe1  00001756c60be8
# e2c8e725  00001756c60be8
# ff7c44ed  00001756c60be8
# 0e7c906e  00001756c60be8
# dd0c804a  00001756c60be8
# 781bbf3c  00001756c60be8
# bd94f005  00001756c60be8
# 62638fba  00001756c60be8
# bb69e88c  00001756c60be8
# 6b5664c7  00001756c60be8
# 23783525  00001756c60be8
# 8522781a  00001756c60be8
# 8ca8392c  00001756c60be8
# 17ec3fc4  00001756c60be8
# 76512d50  00001756c60be8
# a98c5d9f  00001756c60be8
# 06365725  00001756c60be8
# 59959af5  00001756c60be8
# 80151ab7  00001756c60be8
# 5bf9ca51  00001756c60be8
# f5504853  00001756c60be8
# 9f50dca0  00001756c60be8
# 21616367  00001756c60be8
# fcb6792d  00001756c60be8
# 63c26fa2  00001756c60be8
# 4bb2e30a  00001756c60be8
# a6357f7e  00001756c60be8
# 45082c89  00001756c60be8
# 77e56113  00001756c60be8
# 448eb224  00001756c60be8
# 032e2820  00001756c60be8
# 8554b284  00001756c60be8
# 36002912  00001756c60be8
# ac301a84  00001756c60be8
# 23705731  00001756c60be8
# 1496beaf  00001756c60be8
# 2e1a5949  00001756c60be8
# 7e2f170a  00001756c60be8
# bfbde93e  00001756c60be8
# 0d136e08  00001756c60be8
# 915643b3  00001756c60be8
# 8ffe0b25  00001756c60be8
# 8a4c95d1  00001756c60be8
# b69a4f9b  00001756c60be8
# c3ce0945  00001756c60be8
# 3eebeb87  00001756c60be8
# 1ae087ab  00001756c60be8
# aaad8355  00001756c60be8
# 503926eb  00001756c60be8
# 3e5f860d  00001756c60be8

# %%
train_data = pd.concat(
    notebooks_train # The notebooks.
).set_index(
    'id', append=True # Set id as index.
).swaplevel( # Swap cell_id with the notebook id.
).sort_index(
    level='id', sort_remaining=False # Sort by id.
)

# %% [markdown]
# #### HANDLING THE LABELS

# %%
# Get an example notebook.
example_id = train_data.index.unique('id')[42]

# %%
# Unordered notebook.
nb = train_data.loc[example_id, :]
nb;

# %%
# Ordered notebook.
cell_order = train_orders.loc[example_id]
nb.loc[cell_order, :]
# Out:
#          cell_type                                             source
# cell_id
# 21147235  markdown  # Machine intelligence Project:\n## Investigat...
# 6c01d0d2      code  # This Python 3 environment comes with many he...
# 5bd28595  markdown                                 # 1) Data Cleaning
# b8fd3a8c      code  import numpy as np\nimport pandas as pd\nimpor...
# a2501363  markdown  #### First, we will have a view of the data in...
# ...            ...                                                ...
# 9906172a      code  from sklearn.linear_model import RidgeClassifi...
# 5ca1d878  markdown  # Ensembling of  Logistic Regression,KNN, Deci...
# 6dfce6b0      code  import statistics as st\nfinal_pred = np.array...
# 79ea8736  markdown                                       # Conclusion
# bf9eebce  markdown  ### **It was found that the best output is the...
#
# [95 rows x 2 columns]

# %%
# Add the numerically encoded cell ranks.
nb.insert(0, 'rank', encode_orders(nb.index, cell_order))
nb
# Out:
#           rank cell_type                                             source
# cell_id
# 6c01d0d2     1      code  # This Python 3 environment comes with many he...
# b8fd3a8c     3      code  import numpy as np\nimport pandas as pd\nimpor...
# 94d3d43a     5      code                             df.dropna()\ndf.head()
# 9ecece20     6      code                                           df.shape
# 808d31ab     7      code                                         df.columns
# ...        ...       ...                                                ...
# fb5c88e1    47  markdown  ## B- Explorartory Data Analysis\n### After ge...
# ec57b602    59  markdown  #### We have used age and waiting_days columns...
# 449510e4    87  markdown                         # E- SVM Polynomial Kernel
# 9d30d44b    30  markdown  ### 1) What is the ratio between males and fem...
# dff53cea    12  markdown  #### Note 1: The patient_id data type is float...
#
# [95 rows x 3 columns]

# %%
# Get the raw data order (cell_id) and the ground truth order (cell_order).
cell_orders = train_orders.to_frame().join(
    train_data.reset_index("cell_id").groupby("id")["cell_id"].apply(list), how='right'
)

# %%
# Encode all the ranks.
ranks = {}
for id_, cell_order, cell_id in cell_orders.itertuples():
    ranks[id_] = {'cell_id': cell_id, 'rank': encode_orders(cell_id, cell_order)}
    
# Create train ranks dataframe.
train_ranks = pd.DataFrame.from_dict(
    ranks, orient='index'
).rename_axis(
    'id'
).apply(
    pd.Series.explode
).set_index('cell_id', append=True)

# %%
# Merge all pieces of data. 
train = train_data.reset_index().merge(train_ranks, on=['id', 'cell_id']).merge(train_ancestors, on=['id'])

# %%
train["pct_rank"] = train["rank"] / train.groupby("id")["cell_id"].transform("count")
# train[["id", "cell_id", "rank", "pct_rank"]]

# %% [markdown]
# ### SOURCE DATA PREPROCESSING

# %%
nltk.download("wordnet")
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\moses\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\moses\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Get the source text into a dictionary.
source_dict = dict(zip(train['cell_id'].values, train['source'].values))

# Initialize the stemmer.
stemmer = WordNetLemmatizer()

def preprocess_text(document):
    # Remove all the special characters
    document = re.sub(r'\W', ' ', str(document))

    # remove all single characters
    document = re.sub(r'\s+[a-zA-Z]\s+', ' ', document)

    # Remove single characters from the start
    document = re.sub(r'\^[a-zA-Z]\s+', ' ', document)

    # Substituting multiple spaces with single space
    document = re.sub(r'\s+', ' ', document, flags=re.I)

    # Removing prefixed 'b'
    document = re.sub(r'^b\s+', '', document)

    # Converting to Lowercase
    document = document.lower()
    #return document

    # Lemmatization
    tokens = document.split()
    tokens = [stemmer.lemmatize(word) for word in tokens]
    tokens = [word for word in tokens if len(word) > 3]

    preprocessed_text = ' '.join(tokens)
    return preprocessed_text

# %%
# Apply the preprocessing.
train.source = train.source.apply(preprocess_text)

# %% [markdown]
# #### CREATING VALIDATION SET

# %%
val_size = 0.1  # Size of validation set
splitter = GroupShuffleSplit(n_splits=1, test_size=val_size, random_state=0)
train_idx, val_idx = next(splitter.split(train, groups=train["ancestor_id"]))

# %%
trainset = train.loc[train_idx].reset_index(drop=True)
valset = train.loc[val_idx].reset_index(drop=True)

# %%
# Ensure no mix of notebooks with the same ancestors in the two sets.
np.intersect1d(trainset['ancestor_id'].unique(), valset['ancestor_id'].unique())
# Out:
# array([], dtype=object)
